# %%
#unzip gz files
import os
import gzip
import shutil

filenames = os.listdir()
for filename in filenames:
    if filename.endswith('.gz'):
        with gzip.open(filename, 'rb') as f_in:
            with open(filename[:-3], 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
                print(f'{filename} unzipped')
                os.remove(filename)
                print(f'{filename} removed')
    else:
        print(f'{filename} is not a gz file')
# Out:
# ER_diagram.drawio is not a gz file
# users.json is not a gz file
# receipts.json is not a gz file
# brands.json is not a gz file

# %%
import json
import pandas as pd
from pandas import json_normalize

def parse_json(filename):

    with open(filename) as f:
        lines = f.read()
    if 'users' in filename:
        lines = lines.splitlines()[1:-1]

    else:
        lines = lines.splitlines()

    df_tmp = pd.DataFrame(lines)
    df_tmp.columns = ['json_data']
    df_tmp['json_data'].apply(json.loads)
    ret_json = pd.json_normalize(df_tmp['json_data'].apply(json.loads))

    return ret_json


brands_json = parse_json('brands.json')
receipts_json = parse_json('receipts.json')
users_json = parse_json('users.json')

item_table = receipts_json[['_id.$oid', 'rewardsReceiptItemList']]
item_table = item_table.rename(columns={'_id.$oid': 'receipt_id'})
item_table = item_table.explode('rewardsReceiptItemList')

expanded_receipts = json_normalize(item_table['rewardsReceiptItemList'])
item_table = pd.concat([ item_table.reset_index()['receipt_id'],expanded_receipts,], axis=1)

# %%
brands_json.head()
# Out:
#         barcode        category      categoryCode                       name  \
# 0  511111019862          Baking            BAKING  test brand @1612366101024
# 1  511111519928       Beverages         BEVERAGES                  Starbucks
# 2  511111819905          Baking            BAKING  test brand @1612366146176
# 3  511111519874          Baking            BAKING  test brand @1612366146051
# 4  511111319917  Candy & Sweets  CANDY_AND_SWEETS  test brand @1612366146827
#
#   topBrand                  _id.$oid              cpg.$id.$oid cpg.$ref  \
# 0    False  601ac115be37ce2ead437551  601ac114be37ce2ead437550     Cogs
# 1    False  601c5460be37ce2ead43755f  5332f5fbe4b03c9a25efd0ba     Cogs
# 2    False  601ac142be37ce2ead43755d  601ac142be37ce2ead437559     Cogs
# 3    False  601ac142be37ce2ead43755a  601ac142be37ce2ead437559     Cogs
# 4    False  601ac142be37ce2ead43755e  5332fa12e4b03c9a25efd1e7     Cogs
#
#                        brandCode
# 0                            NaN
# ...

# %%
receipts_json.head()
# Out:
#    bonusPointsEarned                            bonusPointsEarnedReason  \
# 0              500.0  Receipt number 2 completed, bonus point schedu...
# 1              150.0  Receipt number 5 completed, bonus point schedu...
# 2                5.0                         All-receipts receipt bonus
# 3                5.0                         All-receipts receipt bonus
# 4                5.0                         All-receipts receipt bonus
#
#   pointsEarned  purchasedItemCount  \
# 0        500.0                 5.0
# 1        150.0                 2.0
# 2            5                 1.0
# 3          5.0                 4.0
# 4          5.0                 2.0
#
#                               rewardsReceiptItemList rewardsReceiptStatus  \
# 0  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 1  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 2  [{'needsFetchReview': False, 'partnerItemId': ...             REJECTED
# ...

# %%
users_json.head()
# Out:
#    active      role signUpSource state                  _id.$oid  \
# 0    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 1    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 2    True  consumer        Email    WI  5ff1e1eacfcf6c399c274ae6
# 3    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 4    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
#
#    createdDate.$date  lastLogin.$date
# 0      1609687444800     1.609688e+12
# 1      1609687444800     1.609688e+12
# 2      1609687530554     1.609688e+12
# 3      1609687444800     1.609688e+12
# 4      1609687444800     1.609688e+12

# %%
item_table.head()
# item_table.columns
# Out:
#                  receipt_id       barcode  \
# 0  5ff1e1eb0a720f0523000575          4011
# 1  5ff1e1bb0a720f052300056b          4011
# 2  5ff1e1bb0a720f052300056b  028400642255
# 3  5ff1e1f10a720f052300057a           NaN
# 4  5ff1e1ee0a7214ada100056f          4011
#
#                                          description finalPrice itemPrice  \
# 0                                     ITEM NOT FOUND      26.00     26.00
# 1                                     ITEM NOT FOUND          1         1
# 2  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...      10.00     10.00
# 3                                                NaN        NaN       NaN
# 4                                     ITEM NOT FOUND      28.00     28.00
#
#   needsFetchReview partnerItemId preventTargetGapPoints  quantityPurchased  \
# 0            False             1                   True                5.0
# 1              NaN             1                    NaN                1.0
# ...

# %% [markdown]
# ## SQL Part

# %%
# 1. What are the top 5 brands by receipts scanned for most recent month?


item_table.merge(brands_json, left_on='brandCode', right_on='_id.$oid')

# %%
#find top 5 brands by receipts scanned 

item_table.groupby('brandCode').size().sort_values(ascending=False).head(5)


# SELECT brandCode, COUNT(*) as count
# FROM item_table
# GROUP BY brandCode
# ORDER BY count DESC
# LIMIT 5;
# Out:
# brandCode
# HY-VEE            291
# BEN AND JERRYS    180
# PEPSI              93
# KROGER             89
# KLEENEX            88
# dtype: int64

# %%
# How does the ranking of the top 5 brands by receipts scanned for the recent month compare to the ranking for the previous month?

# %%
#When considering average spend from receipts with 'rewardsReceiptStatus’ of ‘Accepted’ or ‘Rejected’, which is greater?


receipts_json['totalSpent'] = receipts_json['totalSpent'].astype(float)
receipts_json.groupby('rewardsReceiptStatus')['totalSpent'].sum().head(1).index

# SELECT rewardsReceiptStatus, SUM(totalSpent) as totalSpent
# FROM receipts_json
# where rewardsReceiptStatus in ('Accepted', 'Rejected')
# GROUP BY rewardsReceiptStatus
# ORDER BY totalSpent DESC
# LIMIT 1;
# Out:
# Index(['FINISHED'], dtype='object', name='rewardsReceiptStatus')

# %%
# When considering total number of items purchased from receipts with 'rewardsReceiptStatus’ of ‘Accepted’ or ‘Rejected’, which is greater?

receipts_json['purchasedItemCount'] = receipts_json['purchasedItemCount'].astype(float)
receipts_json.groupby('rewardsReceiptStatus')['purchasedItemCount'].sum()


'''
SELECT rewardsReceiptStatus, SUM(purchasedItemCount) as purchasedItemCount
FROM receipts_json
where rewardsReceiptStatus in ('Accepted', 'Rejected')
GROUP BY rewardsReceiptStatus
ORDER BY purchasedItemCount DESC
LIMIT 1;

'''
# Out:
# rewardsReceiptStatus
# FINISHED     8184.0
# FLAGGED      1014.0
# PENDING         0.0
# REJECTED      173.0
# SUBMITTED       0.0
# Name: purchasedItemCount, dtype: float64

# %%
#Which brand has the most spend among users who were created within the past 6 months?

users_json['createdDate_ts'] = pd.to_datetime(users_json['createdDate.$date'])
users_json
# Out:
#      active         role signUpSource state                  _id.$oid  \
# 0      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 1      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 2      True     consumer        Email    WI  5ff1e1eacfcf6c399c274ae6
# 3      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 4      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# ..      ...          ...          ...   ...                       ...
# 489    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
# 490    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
# 491    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
# 492    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
# 493    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
#
#      createdDate.$date  lastLogin.$date                createdDate_ts
# ...

# %%
#Which brand has the most spend among users who were created within the past 6 months?

# SELECT brandCode, SUM(totalSpent) as totalSpent
# FROM item_table
# WHERE userId in (SELECT _id.$oid
# FROM users_json
# WHERE createdDate.$date > 6 months ago)
# GROUP BY brandCode
# ORDER BY totalSpent DESC

# %%
#Which brand has the most transactions among users who were created within the past 6 months?


item_table
# Out:
#                     receipt_id       barcode  \
# 0     5ff1e1eb0a720f0523000575          4011
# 1     5ff1e1bb0a720f052300056b          4011
# 2     5ff1e1bb0a720f052300056b  028400642255
# 3     5ff1e1f10a720f052300057a           NaN
# 4     5ff1e1ee0a7214ada100056f          4011
# ...                        ...           ...
# 7376  603d0b710a720fde1000042a           NaN
# 7377  603cf5290a720fde10000413           NaN
# 7378  603ce7100a7217c72c000405    B076FJ92M4
# 7379  603ce7100a7217c72c000405    B07BRRLSVC
# 7380  603c4fea0a7217c72c000389           NaN
#
#                                             description finalPrice itemPrice  \
# 0                                        ITEM NOT FOUND      26.00     26.00
# 1                                        ITEM NOT FOUND          1         1
# 2     DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...      10.00     10.00
# 3                                                   NaN        NaN       NaN
# ...

# %% [markdown]
# ## Data Quality Issues

# %% [markdown]
# ### Step 1 : Null Value Check

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def null_value_check(input_df: pd.DataFrame,name:str=None,fig_width=5):
    ''' This function returns a bar plot for null values, ranked by percentage of missing values.
    
    '''
    
    missing_data = input_df.isnull().sum()
    missing_data = missing_data[missing_data >= 0]
    missing_data = (missing_data / len(input_df)) * 100
    print(f'Missing values by percentage for {name}:')
    missing_df =  missing_data.sort_values(ascending=False)
    plt.figure(figsize=(fig_width, 5))
    fig =  sns.barplot(x=missing_df.index, y=missing_df)
    fig.set_xticklabels(fig.get_xticklabels(), rotation=70)

    fig.set_ylabel('Missing values (%)')
    fig.set_xlabel('Columns')
    # fig.show()

    return 

null_value_check(users_json, "Users")
# Out:
# Missing values by percentage for Users:
# /var/folders/qr/fds_zg7j76g51mq0zmqdqfnc0000gn/T/ipykernel_51656/2048860308.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels(fig.get_xticklabels(), rotation=65)

# %%
null_value_check(brands_json, "brands")
# Out:
# Missing values by percentage for brands:
# /var/folders/qr/fds_zg7j76g51mq0zmqdqfnc0000gn/T/ipykernel_51656/2048860308.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels(fig.get_xticklabels(), rotation=65)

# %%
null_value_check(receipts_json, "receipts", fig_width=10)
# Out:
# Missing values by percentage for receipts:
# /var/folders/qr/fds_zg7j76g51mq0zmqdqfnc0000gn/T/ipykernel_51656/2048860308.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels(fig.get_xticklabels(), rotation=65)

# %%
null_value_check(item_table, "items",fig_width=25)
# Out:
# Missing values by percentage for items:
# /var/folders/qr/fds_zg7j76g51mq0zmqdqfnc0000gn/T/ipykernel_51656/2149138837.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels(fig.get_xticklabels(), rotation=70)

# %% [markdown]
# ### Step 2 : Data Duplication Check

# %%
#Duplicate user entries 

print(f'Total Duplicate Rows in Users Data : {users_json.duplicated().sum()}')
users_json[users_json.duplicated(subset=['active','role','_id.$oid','createdDate.$date','lastLogin.$date'])]
# Out:
# Total Duplicate Rows in Users Data : 282
#      active         role signUpSource state                  _id.$oid  \
# 1      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 3      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 4      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 7      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 9      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# ..      ...          ...          ...   ...                       ...
# 489    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
# 490    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
# 491    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
# 492    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
# 493    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
#
#      createdDate.$date  lastLogin.$date
# 1        1609687444800     1.609688e+12
# ...

# %%
#discrepancy on how category,categorycode,_id.$oid and brandcode are represented
#multiple product with same uuid, do have very similar data. So additional fields might be required to indicate which is the active product line.

brands_json[brands_json.duplicated(subset=['category','categoryCode','name'], keep=False)].sort_values(by=['category','categoryCode'])
# Out:
#            barcode            category categoryCode                 name  \
# 126   511111104698                Baby          NaN             Pull-Ups
# 978   511111312949                Baby          NaN             Pull-Ups
# 477   511111304616           Beverages          NaN           V8 Hydrate
# 1025  511111804604           Beverages          NaN           V8 Hydrate
# 1081  511111206330  Breakfast & Cereal          NaN  Dippin Dots® Cereal
# 1163  511111706328  Breakfast & Cereal          NaN  Dippin Dots® Cereal
# 64    511111805854   Health & Wellness          NaN    ONE A DAY® WOMENS
# 339   511111914051   Health & Wellness          NaN    ONE A DAY® WOMENS
# 574   511111605546              Snacks          NaN            Baken-Ets
# 848   511111701781              Snacks          NaN            Baken-Ets
#
#      topBrand                  _id.$oid              cpg.$id.$oid cpg.$ref  \
# 126     False  5bd201a990fa074576779a19  550b2565e4b001d5e9e4146f     Cogs
# ...

# %%
# all the receipt id's are unique - No Duplicates found
receipts_json[receipts_json.duplicated(subset=['_id.$oid',], keep=False)]
# Out:
# Empty DataFrame
# Columns: [bonusPointsEarned, bonusPointsEarnedReason, pointsEarned, purchasedItemCount, rewardsReceiptItemList, rewardsReceiptStatus, totalSpent, userId, _id.$oid, createDate.$date, dateScanned.$date, finishedDate.$date, modifyDate.$date, pointsAwardedDate.$date, purchaseDate.$date]
# Index: []

# %%
#This will identify receipt entries with "ITEM NOT FOUND" in the description, which might indicate issues with barcode scanning or product data.
item_table[item_table.description == 'ITEM NOT FOUND']
# Out:
#                     receipt_id barcode     description finalPrice itemPrice  \
# 0     5ff1e1eb0a720f0523000575    4011  ITEM NOT FOUND      26.00     26.00
# 1     5ff1e1bb0a720f052300056b    4011  ITEM NOT FOUND          1         1
# 4     5ff1e1ee0a7214ada100056f    4011  ITEM NOT FOUND      28.00     28.00
# 5     5ff1e1d20a7214ada1000561    4011  ITEM NOT FOUND          1         1
# 7     5ff1e1e40a7214ada1000566    4011  ITEM NOT FOUND       3.25      3.25
# ...                        ...     ...             ...        ...       ...
# 7186  602538960a720f05a800021b    4011  ITEM NOT FOUND      23.00     23.00
# 7187  602558b40a7214d8e9000263    4011  ITEM NOT FOUND      26.00     26.00
# 7191  60268cab0a7214d8e9000315    4011  ITEM NOT FOUND          1         1
# 7206  60268c7e0a7214d8e9000309    4011  ITEM NOT FOUND      29.00     29.00
# 7211  60268c790a7214d8e9000306    4011  ITEM NOT FOUND      25.00     25.00
#
# ...

# %%
#Receipts with rewardsReceiptStatus marked as "REJECTED" but having pointsEarned greater than 0.

receipts_json.pointsEarned = receipts_json.pointsEarned.astype(float)
receipts_json[(receipts_json.rewardsReceiptStatus == 'REJECTED') & (receipts_json.pointsEarned > 0) ].head()
# Out:
#      bonusPointsEarned                            bonusPointsEarnedReason  \
# 2                  5.0                         All-receipts receipt bonus
# 13               750.0  Receipt number 1 completed, bonus point schedu...
# 62               750.0  Receipt number 1 completed, bonus point schedu...
# 203                5.0                         All-receipts receipt bonus
# 207                5.0                         All-receipts receipt bonus
#
#      pointsEarned  purchasedItemCount  \
# 2             5.0                 1.0
# 13          750.0                11.0
# 62          750.0                 2.0
# 203           5.0                 1.0
# 207           5.0                 1.0
#
#                                 rewardsReceiptItemList rewardsReceiptStatus  \
# 2    [{'needsFetchReview': False, 'partnerItemId': ...             REJECTED
# 13   [{'barcode': '075925306254', 'competitiveProdu...             REJECTED
# ...
